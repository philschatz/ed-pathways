# %%
import pandas as pd

queryresult = pd.read_csv('../data/result.csv')
queryresult
# Out:
#       SchoolID                                    School  \
# 0         1353               Agnes Stewart Middle School
# 1         1353               Agnes Stewart Middle School
# 2         1353               Agnes Stewart Middle School
# 3          694                   Aiken Elementary School
# 4          694                   Aiken Elementary School
# 5          694                   Aiken Elementary School
# 6          692                 Alameda Elementary School
# 7          692                 Alameda Elementary School
# 8          692                 Alameda Elementary School
# 9         3950                     Albany Options School
# 10        3950                     Albany Options School
# 11        3950                     Albany Options School
# 12         943                   Alder Elementary School
# 13         943                   Alder Elementary School
# 14         943                   Alder Elementary School
# ...
