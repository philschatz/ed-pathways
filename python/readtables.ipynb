# %%
import pandas as pd

# %% [markdown]
# ## Summer 2016

# %%
summer2015dt = pd.read_csv('../data/Summer_2015.csv', dtype={ 'SchoolID': str })
summer2015dt
# Out:
#     SchoolID                                            Sponsor  \
# 0         30                                  Corvallis SD 509J
# 1         36                                  Corvallis SD 509J
# 2         39                                  Corvallis SD 509J
# 3         72                              North Clackamas SD 12
# 4         86                              North Clackamas SD 12
# 5         94                                Molalla River SD 35
# 6        107                                  Oregon City SD 62
# 7        115                                  Oregon City SD 62
# 8        119                                  Silver Falls SD 4
# 9        121  Oregon Child Development Coalition, Inc. -  He...
# 10       122                                        Canby SD 86
# 11       130                                        Estacada SD
# 12       143                                         Astoria SD
# 13       144                                         Astoria SD
# ...

# %% [markdown]
# ## OASK

# %%
oaskdt = pd.read_csv('../data/OASK_DB.csv', dtype={ 'SchoolID': str })
oaskdt
# Out:
#      SchoolID                     PROGRAM_SCHOOL_SERVED  \
# 0         NaN                                       NaN
# 1         NaN                                       NaN
# 2         NaN                                       NaN
# 3         NaN                                       NaN
# 4         NaN                                       NaN
# 5         NaN                                       NaN
# 6         NaN                                       NaN
# 7         NaN                                       NaN
# 8         NaN                                       NaN
# 9         NaN                                       NaN
# 10        NaN                                       NaN
# 11        NaN                                       NaN
# 12        NaN                                       NaN
# 13        NaN                                       NaN
# 14        NaN                                       NaN
# 15        NaN                                       NaN
# ...

# %% [markdown]
# ## Performance

# %%
performancedt = pd.read_csv('../data/Performance.csv',dtype={ 'SchoolID': str, 'ParticipationRate2014to2015': pd.np.float64, 'Level3or4in2014to2015': pd.np.float64})
performancedt
# Out:
#        DistrictID              District SchoolID  \
# 0            2063            Adel SD 21      498
# 1            2063            Adel SD 21      498
# 2            2063            Adel SD 21      498
# 3            2063            Adel SD 21      498
# 4            2063            Adel SD 21      498
# 5            2063            Adel SD 21      498
# 6            2063            Adel SD 21      498
# 7            2063            Adel SD 21      498
# 8            2063            Adel SD 21      498
# 9            2063            Adel SD 21      498
# 10           2063            Adel SD 21      498
# 11           2063            Adel SD 21      498
# 12           2063            Adel SD 21      498
# 13           2063            Adel SD 21      498
# 14           2113          Adrian SD 61      707
# 15           2113          Adrian SD 61      707
# 16           2113          Adrian SD 61      707
# 17           2113          Adrian SD 61      707
# ...

# %% [markdown]
# ## RCMediaSchoolsAggregate

# %%
rcmediaschoolsaggregatedt = pd.read_csv('../data/RCmediaSchoolsAggregate.csv', dtype={ 'SchoolID': str})
rcmediaschoolsaggregatedt
# Out:
#       DistrictID                 DistrictName   Superintendent SchoolID  \
# 0           2063                   Adel SD 21   Mary Woodworth      498
# 1           2113                 Adrian SD 61       Gene Mills      707
# 2           2113                 Adrian SD 61       Gene Mills      708
# 3           1899                  Alsea SD 7J       Katie Sapp       16
# 4           1899                  Alsea SD 7J       Katie Sapp       17
# 5           2252                  Amity SD 4J       Jeff Clark     1208
# 6           2252                  Amity SD 4J       Jeff Clark     1210
# 7           2252                  Amity SD 4J       Jeff Clark     1209
# 8           2252                  Amity SD 4J       Jeff Clark     4505
# 9           2111                  Annex SD 29     Steve Bishop      705
# 10          2005               Arlington SD 3    Steve Boynton      323
# 11          2115                  Arock SD 81  Vicki McConnell      711
# ...

# %% [markdown]
# ## FreeReducedLunch

# %%
freereducedlunchdt = pd.read_csv('../data/FreeReducedLunch.csv', dtype={ 'SchoolID': str})
freereducedlunchdt
# Out:
#      SchoolID School_Year_Start  CountyID  DistrictID  Enrollment  \
# 0         498          7/1/2014        19        2063         8.0
# 1         708          7/1/2014        23        2113        80.0
# 2         707          7/1/2014        23        2113       186.0
# 3          17          7/1/2014         2        1899        80.0
# 4          16          7/1/2014         2        1899        92.0
# 5        4505          7/1/2014        36        2252        52.0
# 6        1210          7/1/2014        36        2252       291.0
# 7        1208          7/1/2014        36        2252       353.0
# 8        1209          7/1/2014        36        2252       198.0
# 9         705          7/1/2014        23        2111        66.0
# 10        323          7/1/2014        11        2005       136.0
# 11        711          7/1/2014        23        2115        14.0
# 12       1481          7/1/2014        15        2041        13.0
# ...

# %%
## Absent

# %%
absentdt = pd.read_csv('../data/AbsentReport_1415.csv', dtype={ 'SchoolID': str})
absentdt
# Out:
#        DistrictID        District SchoolID                      School  \
# 0            9999     State Level     9999                 State Level
# 1            9999     State Level     9999                 State Level
# 2            9999     State Level     9999                 State Level
# 3            9999     State Level     9999                 State Level
# 4            9999     State Level     9999                 State Level
# 5            9999     State Level     9999                 State Level
# 6            9999     State Level     9999                 State Level
# 7            9999     State Level     9999                 State Level
# 8            9999     State Level     9999                 State Level
# 9            9999     State Level     9999                 State Level
# 10           9999     State Level     9999                 State Level
# 11           9999     State Level     9999                 State Level
# ...
